# %%
import pandas as pd
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split

# %%
glaucoma_dataset = pd.read_csv('GlaucomaM.csv')

# %%
glaucoma_dataset
# Out:
#         ag     at     as     an     ai    eag    eat    eas    ean    eai  \
# 0    2.220  0.354  0.580  0.686  0.601  1.267  0.336  0.346  0.255  0.331
# 1    2.681  0.475  0.672  0.868  0.667  2.053  0.440  0.520  0.639  0.454
# 2    1.979  0.343  0.508  0.624  0.504  1.200  0.299  0.396  0.259  0.246
# 3    1.747  0.269  0.476  0.525  0.476  0.612  0.147  0.017  0.044  0.405
# 4    2.990  0.599  0.686  1.039  0.667  2.513  0.543  0.607  0.871  0.492
# ..     ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 191  2.801  0.481  0.729  0.888  0.704  1.841  0.312  0.550  0.583  0.396
# 192  1.698  0.265  0.449  0.530  0.454  1.128  0.211  0.281  0.286  0.351
# 193  2.124  0.402  0.514  0.697  0.511  1.595  0.369  0.430  0.323  0.473
# 194  2.039  0.374  0.491  0.675  0.500  1.561  0.362  0.397  0.316  0.485
# 195  2.399  0.433  0.575  0.794  0.597  1.292  0.245  0.484  0.186  0.378
#
#      ...    tmt    tms    tmn    tmi     mr    rnf   mdic    emd     mv  \
# ...

# %%
features = list(glaucoma_dataset.columns)[:-1]

# %%
glaucoma_dataset[features]
# Out:
#         ag     at     as     an     ai    eag    eat    eas    ean    eai  \
# 0    2.220  0.354  0.580  0.686  0.601  1.267  0.336  0.346  0.255  0.331
# 1    2.681  0.475  0.672  0.868  0.667  2.053  0.440  0.520  0.639  0.454
# 2    1.979  0.343  0.508  0.624  0.504  1.200  0.299  0.396  0.259  0.246
# 3    1.747  0.269  0.476  0.525  0.476  0.612  0.147  0.017  0.044  0.405
# 4    2.990  0.599  0.686  1.039  0.667  2.513  0.543  0.607  0.871  0.492
# ..     ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 191  2.801  0.481  0.729  0.888  0.704  1.841  0.312  0.550  0.583  0.396
# 192  1.698  0.265  0.449  0.530  0.454  1.128  0.211  0.281  0.286  0.351
# 193  2.124  0.402  0.514  0.697  0.511  1.595  0.369  0.430  0.323  0.473
# 194  2.039  0.374  0.491  0.675  0.500  1.561  0.362  0.397  0.316  0.485
# 195  2.399  0.433  0.575  0.794  0.597  1.292  0.245  0.484  0.186  0.378
#
#      ...    tmg    tmt    tms    tmn    tmi     mr    rnf   mdic    emd     mv
# ...

# %%
glaucoma_dataset[['Class']]
# Out:
#         Class
# 0      normal
# 1      normal
# 2      normal
# 3      normal
# 4      normal
# ..        ...
# 191  glaucoma
# 192  glaucoma
# 193  glaucoma
# 194  glaucoma
# 195  glaucoma
#
# [196 rows x 1 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(glaucoma_dataset[features], glaucoma_dataset[['Class']], random_state=0)

# %%
print("X_train shape: {}".format(X_train.shape))
print("y_train shape: {}".format(y_train.shape))
# Out:
# X_train shape: (147, 62)
# y_train shape: (147, 1)

# %%
print("X_test shape: {}".format(X_test.shape))
print("y_test shape: {}".format(y_test.shape))
# Out:
# X_test shape: (49, 62)
# y_test shape: (49, 1)

# %%
glaucoma_dataset[features].describe()
# Out:
#                ag          at          as          an          ai         eag  \
# count  196.000000  196.000000  196.000000  196.000000  196.000000  196.000000
# mean     2.606531    0.458980    0.651781    0.835929    0.659995    1.874138
# std      0.659789    0.127013    0.158462    0.222166    0.161065    0.721218
# min      1.312000    0.201000    0.345000    0.397000    0.369000    0.415000
# 25%      2.139250    0.370750    0.538500    0.681000    0.550500    1.309250
# 50%      2.533000    0.444500    0.630500    0.808500    0.632000    1.843500
# 75%      2.943500    0.528000    0.738250    0.952000    0.749750    2.317000
# max      5.444000    0.967000    1.340000    1.765000    1.373000    4.125000
#
#               eat         eas         ean         eai  ...         tmg  \
# count  196.000000  196.000000  196.000000  196.000000  ...  196.000000
# mean     0.406372    0.486403    0.501214    0.480097  ...   -0.092985
# ...

# %%
knn = KNeighborsClassifier(n_neighbors=10)

# %%
np.array(y_train).reshape(147)
# Out:
# array(['normal', 'glaucoma', 'normal', 'normal', 'glaucoma', 'normal',
#        'glaucoma', 'glaucoma', 'normal', 'normal', 'glaucoma', 'glaucoma',
#        'normal', 'glaucoma', 'normal', 'normal', 'glaucoma', 'glaucoma',
#        'glaucoma', 'normal', 'normal', 'glaucoma', 'glaucoma', 'glaucoma',
#        'normal', 'normal', 'normal', 'glaucoma', 'normal', 'glaucoma',
#        'glaucoma', 'normal', 'normal', 'normal', 'glaucoma', 'glaucoma',
#        'normal', 'normal', 'glaucoma', 'normal', 'glaucoma', 'glaucoma',
#        'glaucoma', 'glaucoma', 'normal', 'glaucoma', 'glaucoma',
#        'glaucoma', 'normal', 'normal', 'normal', 'glaucoma', 'normal',
#        'normal', 'glaucoma', 'normal', 'normal', 'normal', 'normal',
#        'normal', 'normal', 'glaucoma', 'normal', 'glaucoma', 'glaucoma',
#        'normal', 'normal', 'normal', 'glaucoma', 'normal', 'glaucoma',
#        'normal', 'normal', 'glaucoma', 'glaucoma', 'glaucoma', 'normal',
# ...

# %%
np.array(X_train)
# Out:
# array([[3.909, 0.652, 1.008, ..., 0.464, 0.587, 0.019],
#        [2.524, 0.474, 0.596, ..., 0.341, 0.376, 0.125],
#        [1.893, 0.327, 0.488, ..., 0.121, 0.203, 0.035],
#        ...,
#        [1.749, 0.264, 0.482, ..., 0.156, 0.251, 0.047],
#        [2.173, 0.336, 0.604, ..., 0.047, 0.102, 0.061],
#        [3.222, 0.567, 0.8  , ..., 0.292, 0.376, 0.03 ]])

# %%
knn.fit(X_train, np.array(y_train).reshape(147))
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=10, p=2,
#                      weights='uniform')

# %%
y_pred = knn.predict(X_test)
print("Test set predictions: {}".format(y_pred))
print("Test set accuracy: {:.2f}%".format(np.mean(y_pred==np.array(y_test).reshape(49))*100))
# Out:
# Test set predictions: ['normal' 'glaucoma' 'normal' 'glaucoma' 'normal' 'glaucoma' 'normal'
#  'normal' 'normal' 'normal' 'normal' 'normal' 'glaucoma' 'glaucoma'
#  'glaucoma' 'glaucoma' 'glaucoma' 'normal' 'normal' 'glaucoma' 'normal'
#  'glaucoma' 'glaucoma' 'glaucoma' 'normal' 'normal' 'glaucoma' 'glaucoma'
#  'glaucoma' 'normal' 'normal' 'glaucoma' 'normal' 'normal' 'glaucoma'
#  'glaucoma' 'normal' 'normal' 'glaucoma' 'glaucoma' 'glaucoma' 'glaucoma'
#  'glaucoma' 'normal' 'normal' 'glaucoma' 'glaucoma' 'glaucoma' 'glaucoma']
# Test set accuracy: 77.55%
