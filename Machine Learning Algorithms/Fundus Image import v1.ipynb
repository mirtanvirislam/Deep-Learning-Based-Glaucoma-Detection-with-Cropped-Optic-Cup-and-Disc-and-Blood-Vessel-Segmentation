# %%
import matplotlib.pyplot as plt
from matplotlib.pyplot import imshow
import matplotlib.image as mpimg
import numpy as np
from PIL import Image

# %matplotlib inline

# %%
pil_im = Image.open('.\Datasets\Fundus_image_test\Im0483_g_ORIGA.jpg', 'r')
imshow(np.asarray(pil_im)) # pil_im.show()

# %%
np.asarray(pil_im).shape
# Out:
# (2048, 3072, 3)

# %%
def rgb2gray(rgb):
    return np.dot(rgb[...,:3], [0.2989, 0.5870, 0.1140])

# %%
img = mpimg.imread('.\Datasets\Fundus_image_test\Im0483_g_ORIGA.jpg')    
gray = rgb2gray(img)

plt.imshow(gray, cmap=plt.get_cmap('gray'), vmin=0, vmax=1)
plt.show()

# %%
import matplotlib.pyplot as plt

from skimage import data
from skimage.color import rgb2gray

original = mpimg.imread('.\Datasets\Fundus_image_test\Im0483_g_ORIGA.jpg')   
grayscale = rgb2gray(original)

fig, axes = plt.subplots(1, 2, figsize=(8, 4))
ax = axes.ravel()

ax[0].imshow(original)
ax[0].set_title("Original")
ax[1].imshow(grayscale, cmap=plt.cm.gray)
ax[1].set_title("Grayscale")

fig.tight_layout()
plt.show()

# %%
grayscale.shape
# Out:
# (2048, 3072)

# %%
grayscale[: :3].shape
# Out:
# (683, 3072)

# %%
imshow(grayscale, cmap=plt.cm.gray)

# %%
imshow(grayscale[::2], cmap=plt.cm.gray)

# %%
np.transpose(grayscale)[::2].shape
# Out:
# (1536, 2048)

# %%
flattened_image = grayscale[::2]
flattened_image = np.transpose(flattened_image)[::2]
flattened_image = np.transpose(flattened_image)
imshow(flattened_image, cmap=plt.cm.gray)
flattened_image.shape
# Out:
# (1024, 1536)
